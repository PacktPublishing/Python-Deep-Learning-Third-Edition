# %% [markdown]
# Install the dependencies:

# %%
# !pip install torch
# !pip install torchvision
# !pip install tensorflow
# !pip install onnx
# !pip install -U tf2onnx
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.1+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (1.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx) (1.23.5)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx) (4.5.0)
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.10/dist-packages (1.15.1)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.23.5)
# Requirement already satisfied: onnx>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (23.5.26)
# Requirement already satisfied: protobuf~=3.20.2 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.4.1->tf2onnx) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2023.7.22)

# %% [markdown]
# Load PyTorch model:

# %%
import torch
from torchvision.models import mobilenet_v3_small, MobileNet_V3_Small_Weights

torch_model = mobilenet_v3_small(
  weights=MobileNet_V3_Small_Weights.DEFAULT)

# %% [markdown]
# Define input and output names for better readability:

# %%
torch.onnx.export(
    model=torch_model,
    args=torch.randn(1, 3, 224, 224),
    f='torch_model.onnx',
    export_params=True,
    verbose=True)
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# Verify the exported model with ONNX:

# %%
import onnx

torch_model_onnx = onnx.load('torch_model.onnx')
onnx.checker.check_model(torch_model_onnx)

print(onnx.helper.printable_graph(torch_model_onnx.graph))
# Out:
# graph torch_jit (
#   %input.1[FLOAT, 1x3x224x224]
# ) initializers (
#   %features.1.block.1.fc1.weight[FLOAT, 8x16x1x1]
#   %features.1.block.1.fc1.bias[FLOAT, 8]
#   %features.1.block.1.fc2.weight[FLOAT, 16x8x1x1]
#   %features.1.block.1.fc2.bias[FLOAT, 16]
#   %features.4.block.2.fc1.weight[FLOAT, 24x96x1x1]
#   %features.4.block.2.fc1.bias[FLOAT, 24]
#   %features.4.block.2.fc2.weight[FLOAT, 96x24x1x1]
#   %features.4.block.2.fc2.bias[FLOAT, 96]
#   %features.5.block.2.fc1.weight[FLOAT, 64x240x1x1]
#   %features.5.block.2.fc1.bias[FLOAT, 64]
#   %features.5.block.2.fc2.weight[FLOAT, 240x64x1x1]
#   %features.5.block.2.fc2.bias[FLOAT, 240]
#   %features.6.block.2.fc1.weight[FLOAT, 64x240x1x1]
#   %features.6.block.2.fc1.bias[FLOAT, 64]
#   %features.6.block.2.fc2.weight[FLOAT, 240x64x1x1]
#   %features.6.block.2.fc2.bias[FLOAT, 240]
#   %features.7.block.2.fc1.weight[FLOAT, 32x120x1x1]
#   %features.7.block.2.fc1.bias[FLOAT, 32]
#   %features.7.block.2.fc2.weight[FLOAT, 120x32x1x1]
#   %features.7.block.2.fc2.bias[FLOAT, 120]
#   %features.8.block.2.fc1.weight[FLOAT, 40x144x1x1]
#   %features.8.block.2.fc1.bias[FLOAT, 40]
#   %features.8.block.2.fc2.weight[FLOAT, 144x40x1x1]
#   %features.8.block.2.fc2.bias[FLOAT, 144]
#   %features.9.block.2.fc1.weight[FLOAT, 72x288x1x1]
#   %features.9.block.2.fc1.bias[FLOAT, 72]
#   %features.9.block.2.fc2.weight[FLOAT, 288x72x1x1]
#   %features.9.block.2.fc2.bias[FLOAT, 288]
#   %features.10.block.2.fc1.weight[FLOAT, 144x576x1x1]
#   %features.10.block.2.fc1.bias[FLOAT, 144]
#   %features.10.block.2.fc2.weight[FLOAT, 576x144x1x1]
#   %features.10.block.2.fc2.bias[FLOAT, 576]
#   %features.11.block.2.fc1.weight[FLOAT, 144x576x1x1]
#   %features.11.block.2.fc1.bias[FLOAT, 144]
#   %features.11.block.2.fc2.weight[FLOAT, 576x144x1x1]
#   %features.11.block.2.fc2.bias[FLOAT, 576]
#   %classifier.0.weight[FLOAT, 1024x576]
#   %classifier.0.bias[FLOAT, 1024]
#   %classifier.3.weight[FLOAT, 1000x1024]
#   %classifier.3.bias[FLOAT, 1000]
#   %onnx::Conv_402[FLOAT, 16x3x3x3]
#   %onnx::Conv_403[FLOAT, 16]
#   %onnx::Conv_405[FLOAT, 16x1x3x3]
#   %onnx::Conv_406[FLOAT, 16]
#   %onnx::Conv_408[FLOAT, 16x16x1x1]
#   %onnx::Conv_409[FLOAT, 16]
#   %onnx::Conv_411[FLOAT, 72x16x1x1]
#   %onnx::Conv_412[FLOAT, 72]
#   %onnx::Conv_414[FLOAT, 72x1x3x3]
#   %onnx::Conv_415[FLOAT, 72]
#   %onnx::Conv_417[FLOAT, 24x72x1x1]
#   %onnx::Conv_418[FLOAT, 24]
#   %onnx::Conv_420[FLOAT, 88x24x1x1]
#   %onnx::Conv_421[FLOAT, 88]
#   %onnx::Conv_423[FLOAT, 88x1x3x3]
#   %onnx::Conv_424[FLOAT, 88]
#   %onnx::Conv_426[FLOAT, 24x88x1x1]
#   %onnx::Conv_427[FLOAT, 24]
#   %onnx::Conv_429[FLOAT, 96x24x1x1]
#   %onnx::Conv_430[FLOAT, 96]
#   %onnx::Conv_432[FLOAT, 96x1x5x5]
#   %onnx::Conv_433[FLOAT, 96]
#   %onnx::Conv_435[FLOAT, 40x96x1x1]
#   %onnx::Conv_436[FLOAT, 40]
#   %onnx::Conv_438[FLOAT, 240x40x1x1]
#   %onnx::Conv_439[FLOAT, 240]
#   %onnx::Conv_441[FLOAT, 240x1x5x5]
#   %onnx::Conv_442[FLOAT, 240]
#   %onnx::Conv_444[FLOAT, 40x240x1x1]
#   %onnx::Conv_445[FLOAT, 40]
#   %onnx::Conv_447[FLOAT, 240x40x1x1]
#   %onnx::Conv_448[FLOAT, 240]
#   %onnx::Conv_450[FLOAT, 240x1x5x5]
#   %onnx::Conv_451[FLOAT, 240]
#   %onnx::Conv_453[FLOAT, 40x240x1x1]
#   %onnx::Conv_454[FLOAT, 40]
#   %onnx::Conv_456[FLOAT, 120x40x1x1]
#   %onnx::Conv_457[FLOAT, 120]
#   %onnx::Conv_459[FLOAT, 120x1x5x5]
#   %onnx::Conv_460[FLOAT, 120]
#   %onnx::Conv_462[FLOAT, 48x120x1x1]
#   %onnx::Conv_463[FLOAT, 48]
#   %onnx::Conv_465[FLOAT, 144x48x1x1]
#   %onnx::Conv_466[FLOAT, 144]
#   %onnx::Conv_468[FLOAT, 144x1x5x5]
#   %onnx::Conv_469[FLOAT, 144]
#   %onnx::Conv_471[FLOAT, 48x144x1x1]
#   %onnx::Conv_472[FLOAT, 48]
#   %onnx::Conv_474[FLOAT, 288x48x1x1]
#   %onnx::Conv_475[FLOAT, 288]
#   %onnx::Conv_477[FLOAT, 288x1x5x5]
#   %onnx::Conv_478[FLOAT, 288]
#   %onnx::Conv_480[FLOAT, 96x288x1x1]
#   %onnx::Conv_481[FLOAT, 96]
#   %onnx::Conv_483[FLOAT, 576x96x1x1]
#   %onnx::Conv_484[FLOAT, 576]
#   %onnx::Conv_486[FLOAT, 576x1x5x5]
#   %onnx::Conv_487[FLOAT, 576]
#   %onnx::Conv_489[FLOAT, 96x576x1x1]
#   %onnx::Conv_490[FLOAT, 96]
#   %onnx::Conv_492[FLOAT, 576x96x1x1]
#   %onnx::Conv_493[FLOAT, 576]
#   %onnx::Conv_495[FLOAT, 576x1x5x5]
#   %onnx::Conv_496[FLOAT, 576]
#   %onnx::Conv_498[FLOAT, 96x576x1x1]
#   %onnx::Conv_499[FLOAT, 96]
#   %onnx::Conv_501[FLOAT, 576x96x1x1]
#   %onnx::Conv_502[FLOAT, 576]
# ) {
#   %/features/features.0/features.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%input.1, %onnx::Conv_402, %onnx::Conv_403)
#   %/features/features.0/features.0.2/HardSwish_output_0 = HardSwish(%/features/features.0/features.0.0/Conv_output_0)
#   %/features/features.1/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 16, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.0/features.0.2/HardSwish_output_0, %onnx::Conv_405, %onnx::Conv_406)
#   %/features/features.1/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.1/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.1/block/block.1/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.1/block/block.0/block.0.2/Relu_output_0)
#   %/features/features.1/block/block.1/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/block/block.1/avgpool/GlobalAveragePool_output_0, %features.1.block.1.fc1.weight, %features.1.block.1.fc1.bias)
#   %/features/features.1/block/block.1/activation/Relu_output_0 = Relu(%/features/features.1/block/block.1/fc1/Conv_output_0)
#   %/features/features.1/block/block.1/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/block/block.1/activation/Relu_output_0, %features.1.block.1.fc2.weight, %features.1.block.1.fc2.bias)
#   %/features/features.1/block/block.1/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.1/block/block.1/fc2/Conv_output_0)
#   %/features/features.1/block/block.1/Mul_output_0 = Mul(%/features/features.1/block/block.1/scale_activation/HardSigmoid_output_0, %/features/features.1/block/block.0/block.0.2/Relu_output_0)
#   %/features/features.1/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/block/block.1/Mul_output_0, %onnx::Conv_408, %onnx::Conv_409)
#   %/features/features.2/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/block/block.2/block.2.0/Conv_output_0, %onnx::Conv_411, %onnx::Conv_412)
#   %/features/features.2/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.2/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.2/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 72, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.2/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_414, %onnx::Conv_415)
#   %/features/features.2/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.2/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.2/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/block/block.1/block.1.2/Relu_output_0, %onnx::Conv_417, %onnx::Conv_418)
#   %/features/features.3/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/block/block.2/block.2.0/Conv_output_0, %onnx::Conv_420, %onnx::Conv_421)
#   %/features/features.3/block/block.0/block.0.2/Relu_output_0 = Relu(%/features/features.3/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.3/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 88, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/block/block.0/block.0.2/Relu_output_0, %onnx::Conv_423, %onnx::Conv_424)
#   %/features/features.3/block/block.1/block.1.2/Relu_output_0 = Relu(%/features/features.3/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.3/block/block.2/block.2.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/block/block.1/block.1.2/Relu_output_0, %onnx::Conv_426, %onnx::Conv_427)
#   %/features/features.3/Add_output_0 = Add(%/features/features.3/block/block.2/block.2.0/Conv_output_0, %/features/features.2/block/block.2/block.2.0/Conv_output_0)
#   %/features/features.4/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/Add_output_0, %onnx::Conv_429, %onnx::Conv_430)
#   %/features/features.4/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.4/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.4/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 96, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [2, 2]](%/features/features.4/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_432, %onnx::Conv_433)
#   %/features/features.4/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.4/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.4/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.4/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.4/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/avgpool/GlobalAveragePool_output_0, %features.4.block.2.fc1.weight, %features.4.block.2.fc1.bias)
#   %/features/features.4/block/block.2/activation/Relu_output_0 = Relu(%/features/features.4/block/block.2/fc1/Conv_output_0)
#   %/features/features.4/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/activation/Relu_output_0, %features.4.block.2.fc2.weight, %features.4.block.2.fc2.bias)
#   %/features/features.4/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.4/block/block.2/fc2/Conv_output_0)
#   %/features/features.4/block/block.2/Mul_output_0 = Mul(%/features/features.4/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.4/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.4/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.2/Mul_output_0, %onnx::Conv_435, %onnx::Conv_436)
#   %/features/features.5/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_438, %onnx::Conv_439)
#   %/features/features.5/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.5/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.5/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 240, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.5/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_441, %onnx::Conv_442)
#   %/features/features.5/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.5/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.5/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.5/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.5/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/avgpool/GlobalAveragePool_output_0, %features.5.block.2.fc1.weight, %features.5.block.2.fc1.bias)
#   %/features/features.5/block/block.2/activation/Relu_output_0 = Relu(%/features/features.5/block/block.2/fc1/Conv_output_0)
#   %/features/features.5/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/activation/Relu_output_0, %features.5.block.2.fc2.weight, %features.5.block.2.fc2.bias)
#   %/features/features.5/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.5/block/block.2/fc2/Conv_output_0)
#   %/features/features.5/block/block.2/Mul_output_0 = Mul(%/features/features.5/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.5/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.5/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/block/block.2/Mul_output_0, %onnx::Conv_444, %onnx::Conv_445)
#   %/features/features.5/Add_output_0 = Add(%/features/features.5/block/block.3/block.3.0/Conv_output_0, %/features/features.4/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.6/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/Add_output_0, %onnx::Conv_447, %onnx::Conv_448)
#   %/features/features.6/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.6/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.6/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 240, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.6/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_450, %onnx::Conv_451)
#   %/features/features.6/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.6/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.6/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.6/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.6/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/avgpool/GlobalAveragePool_output_0, %features.6.block.2.fc1.weight, %features.6.block.2.fc1.bias)
#   %/features/features.6/block/block.2/activation/Relu_output_0 = Relu(%/features/features.6/block/block.2/fc1/Conv_output_0)
#   %/features/features.6/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/activation/Relu_output_0, %features.6.block.2.fc2.weight, %features.6.block.2.fc2.bias)
#   %/features/features.6/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.6/block/block.2/fc2/Conv_output_0)
#   %/features/features.6/block/block.2/Mul_output_0 = Mul(%/features/features.6/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.6/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.6/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/block/block.2/Mul_output_0, %onnx::Conv_453, %onnx::Conv_454)
#   %/features/features.6/Add_output_0 = Add(%/features/features.6/block/block.3/block.3.0/Conv_output_0, %/features/features.5/Add_output_0)
#   %/features/features.7/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/Add_output_0, %onnx::Conv_456, %onnx::Conv_457)
#   %/features/features.7/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.7/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.7/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 120, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.7/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_459, %onnx::Conv_460)
#   %/features/features.7/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.7/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.7/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.7/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.7/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.2/avgpool/GlobalAveragePool_output_0, %features.7.block.2.fc1.weight, %features.7.block.2.fc1.bias)
#   %/features/features.7/block/block.2/activation/Relu_output_0 = Relu(%/features/features.7/block/block.2/fc1/Conv_output_0)
#   %/features/features.7/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.2/activation/Relu_output_0, %features.7.block.2.fc2.weight, %features.7.block.2.fc2.bias)
#   %/features/features.7/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.7/block/block.2/fc2/Conv_output_0)
#   %/features/features.7/block/block.2/Mul_output_0 = Mul(%/features/features.7/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.7/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.7/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.2/Mul_output_0, %onnx::Conv_462, %onnx::Conv_463)
#   %/features/features.8/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_465, %onnx::Conv_466)
#   %/features/features.8/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.8/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.8/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.8/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_468, %onnx::Conv_469)
#   %/features/features.8/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.8/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.8/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.8/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.8/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/block/block.2/avgpool/GlobalAveragePool_output_0, %features.8.block.2.fc1.weight, %features.8.block.2.fc1.bias)
#   %/features/features.8/block/block.2/activation/Relu_output_0 = Relu(%/features/features.8/block/block.2/fc1/Conv_output_0)
#   %/features/features.8/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/block/block.2/activation/Relu_output_0, %features.8.block.2.fc2.weight, %features.8.block.2.fc2.bias)
#   %/features/features.8/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.8/block/block.2/fc2/Conv_output_0)
#   %/features/features.8/block/block.2/Mul_output_0 = Mul(%/features/features.8/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.8/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.8/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/block/block.2/Mul_output_0, %onnx::Conv_471, %onnx::Conv_472)
#   %/features/features.8/Add_output_0 = Add(%/features/features.8/block/block.3/block.3.0/Conv_output_0, %/features/features.7/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.9/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/Add_output_0, %onnx::Conv_474, %onnx::Conv_475)
#   %/features/features.9/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.9/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.9/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 288, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [2, 2]](%/features/features.9/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_477, %onnx::Conv_478)
#   %/features/features.9/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.9/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.9/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.9/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.9/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/block/block.2/avgpool/GlobalAveragePool_output_0, %features.9.block.2.fc1.weight, %features.9.block.2.fc1.bias)
#   %/features/features.9/block/block.2/activation/Relu_output_0 = Relu(%/features/features.9/block/block.2/fc1/Conv_output_0)
#   %/features/features.9/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/block/block.2/activation/Relu_output_0, %features.9.block.2.fc2.weight, %features.9.block.2.fc2.bias)
#   %/features/features.9/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.9/block/block.2/fc2/Conv_output_0)
#   %/features/features.9/block/block.2/Mul_output_0 = Mul(%/features/features.9/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.9/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.9/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/block/block.2/Mul_output_0, %onnx::Conv_480, %onnx::Conv_481)
#   %/features/features.10/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/block/block.3/block.3.0/Conv_output_0, %onnx::Conv_483, %onnx::Conv_484)
#   %/features/features.10/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.10/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.10/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.10/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_486, %onnx::Conv_487)
#   %/features/features.10/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.10/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.10/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.10/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.10/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/block/block.2/avgpool/GlobalAveragePool_output_0, %features.10.block.2.fc1.weight, %features.10.block.2.fc1.bias)
#   %/features/features.10/block/block.2/activation/Relu_output_0 = Relu(%/features/features.10/block/block.2/fc1/Conv_output_0)
#   %/features/features.10/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/block/block.2/activation/Relu_output_0, %features.10.block.2.fc2.weight, %features.10.block.2.fc2.bias)
#   %/features/features.10/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.10/block/block.2/fc2/Conv_output_0)
#   %/features/features.10/block/block.2/Mul_output_0 = Mul(%/features/features.10/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.10/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.10/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/block/block.2/Mul_output_0, %onnx::Conv_489, %onnx::Conv_490)
#   %/features/features.10/Add_output_0 = Add(%/features/features.10/block/block.3/block.3.0/Conv_output_0, %/features/features.9/block/block.3/block.3.0/Conv_output_0)
#   %/features/features.11/block/block.0/block.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/Add_output_0, %onnx::Conv_492, %onnx::Conv_493)
#   %/features/features.11/block/block.0/block.0.2/HardSwish_output_0 = HardSwish(%/features/features.11/block/block.0/block.0.0/Conv_output_0)
#   %/features/features.11/block/block.1/block.1.0/Conv_output_0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%/features/features.11/block/block.0/block.0.2/HardSwish_output_0, %onnx::Conv_495, %onnx::Conv_496)
#   %/features/features.11/block/block.1/block.1.2/HardSwish_output_0 = HardSwish(%/features/features.11/block/block.1/block.1.0/Conv_output_0)
#   %/features/features.11/block/block.2/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.11/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.11/block/block.2/fc1/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/avgpool/GlobalAveragePool_output_0, %features.11.block.2.fc1.weight, %features.11.block.2.fc1.bias)
#   %/features/features.11/block/block.2/activation/Relu_output_0 = Relu(%/features/features.11/block/block.2/fc1/Conv_output_0)
#   %/features/features.11/block/block.2/fc2/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/activation/Relu_output_0, %features.11.block.2.fc2.weight, %features.11.block.2.fc2.bias)
#   %/features/features.11/block/block.2/scale_activation/HardSigmoid_output_0 = HardSigmoid[alpha = 0.16666667163372](%/features/features.11/block/block.2/fc2/Conv_output_0)
#   %/features/features.11/block/block.2/Mul_output_0 = Mul(%/features/features.11/block/block.2/scale_activation/HardSigmoid_output_0, %/features/features.11/block/block.1/block.1.2/HardSwish_output_0)
#   %/features/features.11/block/block.3/block.3.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/block/block.2/Mul_output_0, %onnx::Conv_498, %onnx::Conv_499)
#   %/features/features.11/Add_output_0 = Add(%/features/features.11/block/block.3/block.3.0/Conv_output_0, %/features/features.10/Add_output_0)
#   %/features/features.12/features.12.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/Add_output_0, %onnx::Conv_501, %onnx::Conv_502)
#   %/features/features.12/features.12.2/HardSwish_output_0 = HardSwish(%/features/features.12/features.12.0/Conv_output_0)
#   %/avgpool/GlobalAveragePool_output_0 = GlobalAveragePool(%/features/features.12/features.12.2/HardSwish_output_0)
#   %/Flatten_output_0 = Flatten[axis = 1](%/avgpool/GlobalAveragePool_output_0)
#   %/classifier/classifier.0/Gemm_output_0 = Gemm[alpha = 1, beta = 1, transB = 1](%/Flatten_output_0, %classifier.0.weight, %classifier.0.bias)
#   %/classifier/classifier.1/HardSwish_output_0 = HardSwish(%/classifier/classifier.0/Gemm_output_0)
#   %400 = Gemm[alpha = 1, beta = 1, transB = 1](%/classifier/classifier.1/HardSwish_output_0, %classifier.3.weight, %classifier.3.bias)
#   return %400
# }

# %% [markdown]
# Let's continue with TF. First, load the model:

# %%
import tensorflow as tf

tf_model = tf.keras.applications.MobileNetV3Small(
  weights='imagenet',
  input_shape=(224, 224, 3),
)

# %% [markdown]
# Serialize the model:

# %%
import tf2onnx

tf_model_onnx, _ = tf2onnx.convert.from_keras(
  model=tf_model,
  input_signature=[tf.TensorSpec([1, 224, 224, 3])])
onnx.save(tf_model_onnx, 'tf_model.onnx')
# Out:
# WARNING:tf2onnx.tf_loader:Could not search for non-variable resources. Concrete function internal representation may have changed.

# %% [markdown]
# Verify the model with ONNX:

# %%
tf_model_onnx = onnx.load('tf_model.onnx')
onnx.checker.check_model(tf_model_onnx)

print(onnx.helper.printable_graph(tf_model_onnx.graph))
# Out:
# graph tf2onnx (
#   %args_0[FLOAT, unk__908x224x224x3]
# ) initializers (
#   %pad_const__54[INT64, 8]
#   %pad_const__317[INT64, 8]
#   %const_fold_opt__902[FLOAT, 1x1x1x1]
#   %const_fold_opt__842[INT64, 2]
#   %MobilenetV3small/tf.math.multiply_9/Mul/y:0[FLOAT, scalar]
#   %MobilenetV3small/rescaling/Cast_1/x:0[FLOAT, scalar]
#   %MobilenetV3small/rescaling/Cast/x:0[FLOAT, scalar]
#   %MobilenetV3small/re_lu_18/Relu6_max__257[FLOAT, scalar]
#   %MobilenetV3small/re_lu_17/Relu6_min__246[FLOAT, scalar]
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 576x144x1x1]
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 144x576x1x1]
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 144]
#   %MobilenetV3small/expanded_conv_9/project/Conv2D_weights_fused_bn[FLOAT, 96x576x1x1]
#   %MobilenetV3small/expanded_conv_9/project/Conv2D_bias_fused_bn[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_9/expand/Conv2D_weights_fused_bn[FLOAT, 576x96x1x1]
#   %MobilenetV3small/expanded_conv_9/expand/Conv2D_bias_fused_bn[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_9/depthwise/depthwise_weights_fused_bn[FLOAT, 576x1x5x5]
#   %MobilenetV3small/expanded_conv_9/depthwise/depthwise_bias_fused_bn[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 288x72x1x1]
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 288]
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 72x288x1x1]
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 72]
#   %MobilenetV3small/expanded_conv_8/project/Conv2D_weights_fused_bn[FLOAT, 96x288x1x1]
#   %MobilenetV3small/expanded_conv_8/project/Conv2D_bias_fused_bn[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_8/expand/Conv2D_weights_fused_bn[FLOAT, 288x48x1x1]
#   %MobilenetV3small/expanded_conv_8/expand/Conv2D_bias_fused_bn[FLOAT, 288]
#   %MobilenetV3small/expanded_conv_8/depthwise/depthwise_weights_fused_bn[FLOAT, 288x1x5x5]
#   %MobilenetV3small/expanded_conv_8/depthwise/depthwise_bias_fused_bn[FLOAT, 288]
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 144x40x1x1]
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 144]
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 40x144x1x1]
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 40]
#   %MobilenetV3small/expanded_conv_7/project/Conv2D_weights_fused_bn[FLOAT, 48x144x1x1]
#   %MobilenetV3small/expanded_conv_7/project/Conv2D_bias_fused_bn[FLOAT, 48]
#   %MobilenetV3small/expanded_conv_7/expand/Conv2D_weights_fused_bn[FLOAT, 144x48x1x1]
#   %MobilenetV3small/expanded_conv_7/expand/Conv2D_bias_fused_bn[FLOAT, 144]
#   %MobilenetV3small/expanded_conv_7/depthwise/depthwise_weights_fused_bn[FLOAT, 144x1x5x5]
#   %MobilenetV3small/expanded_conv_7/depthwise/depthwise_bias_fused_bn[FLOAT, 144]
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 120x32x1x1]
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 120]
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 32x120x1x1]
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 32]
#   %MobilenetV3small/expanded_conv_6/project/Conv2D_weights_fused_bn[FLOAT, 48x120x1x1]
#   %MobilenetV3small/expanded_conv_6/project/Conv2D_bias_fused_bn[FLOAT, 48]
#   %MobilenetV3small/expanded_conv_6/expand/Conv2D_weights_fused_bn[FLOAT, 120x40x1x1]
#   %MobilenetV3small/expanded_conv_6/expand/Conv2D_bias_fused_bn[FLOAT, 120]
#   %MobilenetV3small/expanded_conv_6/depthwise/depthwise_weights_fused_bn[FLOAT, 120x1x5x5]
#   %MobilenetV3small/expanded_conv_6/depthwise/depthwise_bias_fused_bn[FLOAT, 120]
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 240x64x1x1]
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 64x240x1x1]
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 64]
#   %MobilenetV3small/expanded_conv_5/project/Conv2D_weights_fused_bn[FLOAT, 40x240x1x1]
#   %MobilenetV3small/expanded_conv_5/project/Conv2D_bias_fused_bn[FLOAT, 40]
#   %MobilenetV3small/expanded_conv_5/expand/Conv2D_weights_fused_bn[FLOAT, 240x40x1x1]
#   %MobilenetV3small/expanded_conv_5/expand/Conv2D_bias_fused_bn[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_5/depthwise/depthwise_weights_fused_bn[FLOAT, 240x1x5x5]
#   %MobilenetV3small/expanded_conv_5/depthwise/depthwise_bias_fused_bn[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 240x64x1x1]
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 64x240x1x1]
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 64]
#   %MobilenetV3small/expanded_conv_4/project/Conv2D_weights_fused_bn[FLOAT, 40x240x1x1]
#   %MobilenetV3small/expanded_conv_4/project/Conv2D_bias_fused_bn[FLOAT, 40]
#   %MobilenetV3small/expanded_conv_4/expand/Conv2D_weights_fused_bn[FLOAT, 240x40x1x1]
#   %MobilenetV3small/expanded_conv_4/expand/Conv2D_bias_fused_bn[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_4/depthwise/depthwise_weights_fused_bn[FLOAT, 240x1x5x5]
#   %MobilenetV3small/expanded_conv_4/depthwise/depthwise_bias_fused_bn[FLOAT, 240]
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 96x24x1x1]
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 24x96x1x1]
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 24]
#   %MobilenetV3small/expanded_conv_3/project/Conv2D_weights_fused_bn[FLOAT, 40x96x1x1]
#   %MobilenetV3small/expanded_conv_3/project/Conv2D_bias_fused_bn[FLOAT, 40]
#   %MobilenetV3small/expanded_conv_3/expand/Conv2D_weights_fused_bn[FLOAT, 96x24x1x1]
#   %MobilenetV3small/expanded_conv_3/expand/Conv2D_bias_fused_bn[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_3/depthwise/depthwise_weights_fused_bn[FLOAT, 96x1x5x5]
#   %MobilenetV3small/expanded_conv_3/depthwise/depthwise_bias_fused_bn[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_2/project/Conv2D_weights_fused_bn[FLOAT, 24x88x1x1]
#   %MobilenetV3small/expanded_conv_2/project/Conv2D_bias_fused_bn[FLOAT, 24]
#   %MobilenetV3small/expanded_conv_2/expand/Conv2D_weights_fused_bn[FLOAT, 88x24x1x1]
#   %MobilenetV3small/expanded_conv_2/expand/Conv2D_bias_fused_bn[FLOAT, 88]
#   %MobilenetV3small/expanded_conv_2/depthwise/depthwise_weights_fused_bn[FLOAT, 88x1x3x3]
#   %MobilenetV3small/expanded_conv_2/depthwise/depthwise_bias_fused_bn[FLOAT, 88]
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 576x144x1x1]
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 144x576x1x1]
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 144]
#   %MobilenetV3small/expanded_conv_10/project/Conv2D_weights_fused_bn[FLOAT, 96x576x1x1]
#   %MobilenetV3small/expanded_conv_10/project/Conv2D_bias_fused_bn[FLOAT, 96]
#   %MobilenetV3small/expanded_conv_10/expand/Conv2D_weights_fused_bn[FLOAT, 576x96x1x1]
#   %MobilenetV3small/expanded_conv_10/expand/Conv2D_bias_fused_bn[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_10/depthwise/depthwise_weights_fused_bn[FLOAT, 576x1x5x5]
#   %MobilenetV3small/expanded_conv_10/depthwise/depthwise_bias_fused_bn[FLOAT, 576]
#   %MobilenetV3small/expanded_conv_1/project/Conv2D_weights_fused_bn[FLOAT, 24x72x1x1]
#   %MobilenetV3small/expanded_conv_1/project/Conv2D_bias_fused_bn[FLOAT, 24]
#   %MobilenetV3small/expanded_conv_1/expand/Conv2D_weights_fused_bn[FLOAT, 72x16x1x1]
#   %MobilenetV3small/expanded_conv_1/expand/Conv2D_bias_fused_bn[FLOAT, 72]
#   %MobilenetV3small/expanded_conv_1/depthwise/depthwise_weights_fused_bn[FLOAT, 72x1x3x3]
#   %MobilenetV3small/expanded_conv_1/depthwise/depthwise_bias_fused_bn[FLOAT, 72]
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0[FLOAT, 16x8x1x1]
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0[FLOAT, 16]
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv/Conv2D/ReadVariableOp:0[FLOAT, 8x16x1x1]
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0[FLOAT, 8]
#   %MobilenetV3small/expanded_conv/project/Conv2D_weights_fused_bn[FLOAT, 16x16x1x1]
#   %MobilenetV3small/expanded_conv/project/Conv2D_bias_fused_bn[FLOAT, 16]
#   %MobilenetV3small/expanded_conv/depthwise/depthwise_weights_fused_bn[FLOAT, 16x1x3x3]
#   %MobilenetV3small/expanded_conv/depthwise/depthwise_bias_fused_bn[FLOAT, 16]
#   %MobilenetV3small/Logits/Conv2D/ReadVariableOp:0[FLOAT, 1000x1024x1x1]
#   %MobilenetV3small/Logits/BiasAdd/ReadVariableOp:0[FLOAT, 1000]
#   %MobilenetV3small/Conv_2/Conv2D/ReadVariableOp:0[FLOAT, 1024x576x1x1]
#   %MobilenetV3small/Conv_2/BiasAdd/ReadVariableOp:0[FLOAT, 1024]
#   %MobilenetV3small/Conv_1/Conv2D_weights_fused_bn[FLOAT, 576x96x1x1]
#   %MobilenetV3small/Conv_1/Conv2D_bias_fused_bn[FLOAT, 576]
#   %MobilenetV3small/Conv/Conv2D_weights_fused_bn[FLOAT, 16x3x3x3]
#   %MobilenetV3small/Conv/Conv2D_bias_fused_bn[FLOAT, 16]
# ) {
#   %MobilenetV3small/rescaling/mul:0 = Mul(%args_0, %MobilenetV3small/rescaling/Cast/x:0)
#   %MobilenetV3small/rescaling/add:0 = Add(%MobilenetV3small/rescaling/mul:0, %MobilenetV3small/rescaling/Cast_1/x:0)
#   %MobilenetV3small/Conv/Conv2D__6:0 = Transpose[perm = [0, 3, 1, 2]](%MobilenetV3small/rescaling/add:0)
#   %MobilenetV3small/Conv/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [0, 0, 1, 1], strides = [2, 2]](%MobilenetV3small/Conv/Conv2D__6:0, %MobilenetV3small/Conv/Conv2D_weights_fused_bn, %MobilenetV3small/Conv/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add/AddV2:0 = Add(%MobilenetV3small/Conv/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply/Mul:0 = Mul(%MobilenetV3small/re_lu/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply/mul:0 = Mul(%MobilenetV3small/Conv/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply/Mul:0)
#   %MobilenetV3small/expanded_conv/depthwise/pad/Pad:0 = Pad(%MobilenetV3small/multiply/mul:0, %pad_const__54)
#   %MobilenetV3small/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 16, kernel_shape = [3, 3], strides = [2, 2]](%MobilenetV3small/expanded_conv/depthwise/pad/Pad:0, %MobilenetV3small/expanded_conv/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/re_lu_1/Relu:0 = Relu(%MobilenetV3small/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/re_lu_1/Relu:0)
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_1/AddV2:0 = Add(%MobilenetV3small/expanded_conv/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_2/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_1/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_1/Mul:0 = Mul(%MobilenetV3small/re_lu_2/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/re_lu_1/Relu:0, %MobilenetV3small/tf.math.multiply_1/Mul:0)
#   %MobilenetV3small/expanded_conv/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_1/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_1/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/re_lu_3/Relu:0 = Relu(%MobilenetV3small/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_1/depthwise/pad/Pad:0 = Pad(%MobilenetV3small/re_lu_3/Relu:0, %pad_const__54)
#   %MobilenetV3small/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 72, kernel_shape = [3, 3], strides = [2, 2]](%MobilenetV3small/expanded_conv_1/depthwise/pad/Pad:0, %MobilenetV3small/expanded_conv_1/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_1/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/re_lu_4/Relu:0 = Relu(%MobilenetV3small/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_1/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/re_lu_4/Relu:0, %MobilenetV3small/expanded_conv_1/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_1/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_1/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_2/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_2/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/re_lu_5/Relu:0 = Relu(%MobilenetV3small/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 88, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%MobilenetV3small/re_lu_5/Relu:0, %MobilenetV3small/expanded_conv_2/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_2/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/re_lu_6/Relu:0 = Relu(%MobilenetV3small/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_2/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/re_lu_6/Relu:0, %MobilenetV3small/expanded_conv_2/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_2/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_2/Add/add:0 = Add(%MobilenetV3small/expanded_conv_1/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_2/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_2/Add/add:0, %MobilenetV3small/expanded_conv_3/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_3/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_2/AddV2:0 = Add(%MobilenetV3small/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_7/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_2/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_2/Mul:0 = Mul(%MobilenetV3small/re_lu_7/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_1/mul:0 = Mul(%MobilenetV3small/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_2/Mul:0)
#   %MobilenetV3small/expanded_conv_3/depthwise/pad/Pad:0 = Pad(%MobilenetV3small/multiply_1/mul:0, %pad_const__317)
#   %MobilenetV3small/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 96, kernel_shape = [5, 5], strides = [2, 2]](%MobilenetV3small/expanded_conv_3/depthwise/pad/Pad:0, %MobilenetV3small/expanded_conv_3/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_3/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_3/AddV2:0 = Add(%MobilenetV3small/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_8/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_3/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_3/Mul:0 = Mul(%MobilenetV3small/re_lu_8/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_2/mul:0 = Mul(%MobilenetV3small/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_3/Mul:0)
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_2/mul:0)
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_3/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_3/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_3/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_4/AddV2:0 = Add(%MobilenetV3small/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_9/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_4/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_4/Mul:0 = Mul(%MobilenetV3small/re_lu_9/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_3/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_2/mul:0, %MobilenetV3small/tf.math.multiply_4/Mul:0)
#   %MobilenetV3small/expanded_conv_3/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_3/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_3/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_3/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_3/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_4/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_4/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_5/AddV2:0 = Add(%MobilenetV3small/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_10/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_5/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_5/Mul:0 = Mul(%MobilenetV3small/re_lu_10/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_3/mul:0 = Mul(%MobilenetV3small/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_5/Mul:0)
#   %MobilenetV3small/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 240, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_3/mul:0, %MobilenetV3small/expanded_conv_4/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_4/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_6/AddV2:0 = Add(%MobilenetV3small/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_11/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_6/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_6/Mul:0 = Mul(%MobilenetV3small/re_lu_11/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_4/mul:0 = Mul(%MobilenetV3small/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_6/Mul:0)
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_4/mul:0)
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_4/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_4/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_4/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_7/AddV2:0 = Add(%MobilenetV3small/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_12/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_7/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_7/Mul:0 = Mul(%MobilenetV3small/re_lu_12/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_4/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_4/mul:0, %MobilenetV3small/tf.math.multiply_7/Mul:0)
#   %MobilenetV3small/expanded_conv_4/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_4/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_4/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_4/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_4/Add/add:0 = Add(%MobilenetV3small/expanded_conv_3/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_4/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_4/Add/add:0, %MobilenetV3small/expanded_conv_5/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_5/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_8/AddV2:0 = Add(%MobilenetV3small/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_13/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_8/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_8/Mul:0 = Mul(%MobilenetV3small/re_lu_13/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_5/mul:0 = Mul(%MobilenetV3small/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_8/Mul:0)
#   %MobilenetV3small/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 240, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_5/mul:0, %MobilenetV3small/expanded_conv_5/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_5/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_9/AddV2:0 = Add(%MobilenetV3small/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_14/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_9/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_9/Mul:0 = Mul(%MobilenetV3small/re_lu_14/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_6/mul:0 = Mul(%MobilenetV3small/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_9/Mul:0)
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_6/mul:0)
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_5/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_5/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_5/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_10/AddV2:0 = Add(%MobilenetV3small/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_15/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_10/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_10/Mul:0 = Mul(%MobilenetV3small/re_lu_15/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_5/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_6/mul:0, %MobilenetV3small/tf.math.multiply_10/Mul:0)
#   %MobilenetV3small/expanded_conv_5/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_5/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_5/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_5/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_5/Add/add:0 = Add(%MobilenetV3small/expanded_conv_4/Add/add:0, %MobilenetV3small/expanded_conv_5/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_5/Add/add:0, %MobilenetV3small/expanded_conv_6/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_6/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_11/AddV2:0 = Add(%MobilenetV3small/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_16/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_11/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_11/Mul:0 = Mul(%MobilenetV3small/re_lu_16/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_7/mul:0 = Mul(%MobilenetV3small/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_11/Mul:0)
#   %MobilenetV3small/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 120, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_7/mul:0, %MobilenetV3small/expanded_conv_6/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_6/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_12/AddV2:0 = Add(%MobilenetV3small/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_17/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_12/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_12/Mul:0 = Mul(%MobilenetV3small/re_lu_17/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_8/mul:0 = Mul(%MobilenetV3small/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_12/Mul:0)
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_8/mul:0)
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_6/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_6/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_6/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_13/AddV2:0 = Add(%MobilenetV3small/expanded_conv_6/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_18/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_13/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_13/Mul:0 = Mul(%MobilenetV3small/re_lu_18/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_6/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_8/mul:0, %MobilenetV3small/tf.math.multiply_13/Mul:0)
#   %MobilenetV3small/expanded_conv_6/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_6/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_6/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_6/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_6/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_7/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_7/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_14/AddV2:0 = Add(%MobilenetV3small/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_19/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_14/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_14/Mul:0 = Mul(%MobilenetV3small/re_lu_19/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_9/mul:0 = Mul(%MobilenetV3small/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_14/Mul:0)
#   %MobilenetV3small/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_9/mul:0, %MobilenetV3small/expanded_conv_7/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_7/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_15/AddV2:0 = Add(%MobilenetV3small/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_20/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_15/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_15/Mul:0 = Mul(%MobilenetV3small/re_lu_20/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_10/mul:0 = Mul(%MobilenetV3small/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_15/Mul:0)
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_10/mul:0)
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_7/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_7/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_7/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_16/AddV2:0 = Add(%MobilenetV3small/expanded_conv_7/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_21/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_16/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_16/Mul:0 = Mul(%MobilenetV3small/re_lu_21/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_7/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_10/mul:0, %MobilenetV3small/tf.math.multiply_16/Mul:0)
#   %MobilenetV3small/expanded_conv_7/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_7/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_7/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_7/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_7/Add/add:0 = Add(%MobilenetV3small/expanded_conv_6/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_7/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_7/Add/add:0, %MobilenetV3small/expanded_conv_8/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_8/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_17/AddV2:0 = Add(%MobilenetV3small/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_22/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_17/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_17/Mul:0 = Mul(%MobilenetV3small/re_lu_22/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_11/mul:0 = Mul(%MobilenetV3small/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_17/Mul:0)
#   %MobilenetV3small/expanded_conv_8/depthwise/pad/Pad:0 = Pad(%MobilenetV3small/multiply_11/mul:0, %pad_const__317)
#   %MobilenetV3small/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 288, kernel_shape = [5, 5], strides = [2, 2]](%MobilenetV3small/expanded_conv_8/depthwise/pad/Pad:0, %MobilenetV3small/expanded_conv_8/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_8/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_18/AddV2:0 = Add(%MobilenetV3small/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_23/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_18/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_18/Mul:0 = Mul(%MobilenetV3small/re_lu_23/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_12/mul:0 = Mul(%MobilenetV3small/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_18/Mul:0)
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_12/mul:0)
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_8/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_8/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_8/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_19/AddV2:0 = Add(%MobilenetV3small/expanded_conv_8/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_24/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_19/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_19/Mul:0 = Mul(%MobilenetV3small/re_lu_24/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_8/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_12/mul:0, %MobilenetV3small/tf.math.multiply_19/Mul:0)
#   %MobilenetV3small/expanded_conv_8/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_8/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_8/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_8/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_8/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_9/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_9/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_20/AddV2:0 = Add(%MobilenetV3small/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_25/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_20/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_20/Mul:0 = Mul(%MobilenetV3small/re_lu_25/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_13/mul:0 = Mul(%MobilenetV3small/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_20/Mul:0)
#   %MobilenetV3small/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_13/mul:0, %MobilenetV3small/expanded_conv_9/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_9/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_21/AddV2:0 = Add(%MobilenetV3small/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_26/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_21/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_21/Mul:0 = Mul(%MobilenetV3small/re_lu_26/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_14/mul:0 = Mul(%MobilenetV3small/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_21/Mul:0)
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_14/mul:0)
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_9/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_9/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_9/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_22/AddV2:0 = Add(%MobilenetV3small/expanded_conv_9/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_27/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_22/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_22/Mul:0 = Mul(%MobilenetV3small/re_lu_27/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_9/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_14/mul:0, %MobilenetV3small/tf.math.multiply_22/Mul:0)
#   %MobilenetV3small/expanded_conv_9/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_9/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_9/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_9/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_9/Add/add:0 = Add(%MobilenetV3small/expanded_conv_8/project/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/expanded_conv_9/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_9/Add/add:0, %MobilenetV3small/expanded_conv_10/expand/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_10/expand/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_23/AddV2:0 = Add(%MobilenetV3small/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_28/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_23/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_23/Mul:0 = Mul(%MobilenetV3small/re_lu_28/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_15/mul:0 = Mul(%MobilenetV3small/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_23/Mul:0)
#   %MobilenetV3small/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%MobilenetV3small/multiply_15/mul:0, %MobilenetV3small/expanded_conv_10/depthwise/depthwise_weights_fused_bn, %MobilenetV3small/expanded_conv_10/depthwise/depthwise_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_24/AddV2:0 = Add(%MobilenetV3small/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_29/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_24/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_24/Mul:0 = Mul(%MobilenetV3small/re_lu_29/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_16/mul:0 = Mul(%MobilenetV3small/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_24/Mul:0)
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/AvgPool/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_16/mul:0)
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_10/squeeze_excite/AvgPool/Mean:0, %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Relu/Relu:0 = Relu(%MobilenetV3small/expanded_conv_10/squeeze_excite/Conv/BiasAdd:0)
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_10/squeeze_excite/Relu/Relu:0, %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/Conv2D/ReadVariableOp:0, %MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_25/AddV2:0 = Add(%MobilenetV3small/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_30/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_25/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_25/Mul:0 = Mul(%MobilenetV3small/re_lu_30/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/expanded_conv_10/squeeze_excite/Mul/mul:0 = Mul(%MobilenetV3small/multiply_16/mul:0, %MobilenetV3small/tf.math.multiply_25/Mul:0)
#   %MobilenetV3small/expanded_conv_10/project/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_10/squeeze_excite/Mul/mul:0, %MobilenetV3small/expanded_conv_10/project/Conv2D_weights_fused_bn, %MobilenetV3small/expanded_conv_10/project/Conv2D_bias_fused_bn)
#   %MobilenetV3small/expanded_conv_10/Add/add:0 = Add(%MobilenetV3small/expanded_conv_9/Add/add:0, %MobilenetV3small/expanded_conv_10/project/BatchNorm/FusedBatchNormV3:0)
#   %MobilenetV3small/Conv_1/BatchNorm/FusedBatchNormV3:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/expanded_conv_10/Add/add:0, %MobilenetV3small/Conv_1/Conv2D_weights_fused_bn, %MobilenetV3small/Conv_1/Conv2D_bias_fused_bn)
#   %MobilenetV3small/tf.__operators__.add_26/AddV2:0 = Add(%MobilenetV3small/Conv_1/BatchNorm/FusedBatchNormV3:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_31/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_26/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_26/Mul:0 = Mul(%MobilenetV3small/re_lu_31/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_17/mul:0 = Mul(%MobilenetV3small/Conv_1/BatchNorm/FusedBatchNormV3:0, %MobilenetV3small/tf.math.multiply_26/Mul:0)
#   %MobilenetV3small/global_average_pooling2d/Mean:0 = GlobalAveragePool(%MobilenetV3small/multiply_17/mul:0)
#   %MobilenetV3small/Conv_2/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/global_average_pooling2d/Mean:0, %MobilenetV3small/Conv_2/Conv2D/ReadVariableOp:0, %MobilenetV3small/Conv_2/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/tf.__operators__.add_27/AddV2:0 = Add(%MobilenetV3small/Conv_2/BiasAdd:0, %const_fold_opt__902)
#   %MobilenetV3small/re_lu_32/Relu6:0 = Clip(%MobilenetV3small/tf.__operators__.add_27/AddV2:0, %MobilenetV3small/re_lu_17/Relu6_min__246, %MobilenetV3small/re_lu_18/Relu6_max__257)
#   %MobilenetV3small/tf.math.multiply_27/Mul:0 = Mul(%MobilenetV3small/re_lu_32/Relu6:0, %MobilenetV3small/tf.math.multiply_9/Mul/y:0)
#   %MobilenetV3small/multiply_18/mul:0 = Mul(%MobilenetV3small/Conv_2/BiasAdd:0, %MobilenetV3small/tf.math.multiply_27/Mul:0)
#   %MobilenetV3small/Logits/BiasAdd:0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%MobilenetV3small/multiply_18/mul:0, %MobilenetV3small/Logits/Conv2D/ReadVariableOp:0, %MobilenetV3small/Logits/BiasAdd/ReadVariableOp:0)
#   %MobilenetV3small/flatten/Reshape:0 = Reshape(%MobilenetV3small/Logits/BiasAdd:0, %const_fold_opt__842)
#   %Predictions = Softmax(%MobilenetV3small/flatten/Reshape:0)
#   return %Predictions
# }
